# %% [markdown]
# <a href="https://colab.research.google.com/github/necronet/Notebooks/blob/master/DSP/introthinkDSP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py
# Out:
# --2020-07-25 19:01:55--  https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkdsp.py [following]
# --2020-07-25 19:01:56--  https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkdsp.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48706 (48K) [text/plain]
# Saving to: ‘thinkdsp.py’
#
# thinkdsp.py         100%[===================>]  47.56K  --.-KB/s    in 0.03s
#
# 2020-07-25 19:01:56 (1.81 MB/s) - ‘thinkdsp.py’ saved [48706/48706]

# %%
from thinkdsp import CosSignal, SinSignal

cos_sig = CosSignal(freq=440, amp=1.0, offset=0)
sin_sig = SinSignal(freq=880, amp=0.5, offset=0)

# %%
from thinkdsp import decorate

cos_sig.plot()
decorate(xlabel='Time (s)')

# %%
sin_sig.plot()
decorate(xlabel='Time (s)')

# %%
mix = sin_sig + cos_sig
mix

# %%
mix.plot()
decorate(xlabel='Time (s)')

# %%
wave = mix.make_wave(duration=0.5, start=0, framerate=11025)
wave

# %%
from IPython.display import Audio
audio = Audio(data=wave.ys, rate=wave.framerate)
audio
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
segment = wave.segment(start=0, duration=.05)
segment.plot()

# %%
spectrum = wave.make_spectrum()
spectrum.plot()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Checking audiodataset is available
! ls "/content/drive/My Drive/Colab Notebooks/Dataset/audio/"
# Out:
# 92002__jcveliz__violin-origional.wav

# %%
from thinkdsp import read_wave

wave = read_wave('/content/drive/My Drive/Colab Notebooks/Dataset/audio/92002__jcveliz__violin-origional.wav')
wave.plot()

# %%
spectrum = wave.make_spectrum()
spectrum.plot()

# %%
spectrum.low_pass(cutoff=2000, factor=0.01)

# %%
spectrum.plot()

# %%
spectrum.make_wave().make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrum.high_pass(cutoff=800, factor=0.01)
spectrum.make_wave().make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
